# %% [markdown]
# # Fundamentals of Radio Interferometry

# %% [markdown]
# Interferometry is a fundamental technique used in radio astronomy but is difficult to understand. The technique is rarely used in other fields of astronomy and physics. Many of our intutions about imaging, which comes from cameras and out own eyes, hide the underlying transformations which are central to interferometer theory. With this book we hope to present a useful entry point into the topic by sticking to the fundamentals of the topic which is appropriate for a masters or doctoral student who is starting on the subject.
#
# As this is meant to be a living and evolving document with a number of contributors, any help is regards to content, editing, or presentation are welcome. We are striving to create the book which we did not have when first learning interferometry.

# %% [markdown]
# ### Outline <a id='preface:sec:outline'></a>
#
# * Preface
#     1. [Outline](#preface:sec:outline)
#     2. [A Note on Software](#preface:sec:software)
#     3. [Style Guide](#preface:sec:style)
#     4. [Known Issues](#preface:sec:issues)
#     5. [Glossary](1_glossary.ipynb#preface:sec:glossary)
#
#
# 1. Radio Science using Interferometers
#     1. What are we trying to do? What is the point?
#     2. What arrays exist, what are they used for, and why so much diversity?
# 2. Mathematical Groundwork
#     1. Complex Numbers
#     2. Fourier Transforms
#         1. The Fourier Transform
#         2. The Discrete Fourier Transform (DFT) and the Fast Fourier Transform (FFT)
#     3. Convolution
#         1. The Convolution Theorem
#         2. Correlation Relations
#     4. Sampling Theory
#     5. Linear Algrebra
#         1. Basic Properties and Relationships
#         2. Jones Matricies and Polarization
#         3. Matrix Products (outer product, khatri-rao product, hadamard product and the relations between all these operators... (The three most used identities in calibration when expressing the RIME))
#         4. Matrix Inversion
#         5. Mueller Matricies
#     6. Least-squares Minimization
# 3. Positional Astronomy
#     1. [The Celestial Sphere (RA, Dec)](../3_Positional_Astronomy/1_the_celestial_sphere.ipynb)
#     2. Local Sidereal Time (LST, HA)
#     3. Equatorial (X,Y,Z)
# 4. Visibility Space
#     1. The Baseline: 2-element interferometer
#     2. Correlation and the van Cittert-Zernike Theorem
#     3. Fringe-tracking
#     4. (u,v,w) visibility-space, w-term
#     5. (l,m,n) image-space
#     6. Rotational Synthesis
#     7. Baselines in Arrays
#     8. Integrations, Channel Widths, Time and Frequency Smearing
# 5. [Imaging](../5_Imaging/0_introduction.ipynb)
#     1. [Spatial Frequencies](../5_Imaging/1_spatial_frequencies.ipynb)
#     2. Sampling and Point Spread Functions
#     3. Gridding and Degridding for using the FFT
#     4. The Dirty Image and Visibility Weightings
#     5. The Break Down of the Small Angle Approximation and the W-Term
# 6. Deconvolution in Imaging
#     1. Sky Models
#     2. Point Source Assumption (CLEAN)
#         1. A simple 1D deconvolution example
#         2. Image-domain (Hogbom)
#         3. Gridded Visibility-domain (Clark)
#         4. Visibility domain (Cotton-Schwab)
#     3. Residuals and Image Quality
#     4. Source Finding and Detection
# 7. Observing Systems
#     1. Jones Notation
#     2. The Measurement Equation
#     3. Direction-dependent and Independent effects
#     4. Electronics: bandpass, gain variation, system noise/sensitivity
#     5. Primary Beam
#     6. Feeds: polarization and leakage
#     7. Antenna Mounts and Parallactic Angle
#     8. Ionosphere/Atmosphere
#     9. Radio Frequency Interference (RFI)
# 8. Calibration
#     1. Jones Formalism of the Measurement Equation
#     2. Calibration as a Matrix Inversion
#     3. 1GC calibration: point source, derive bandpass gains
#     4. 2GC calibration: direction-independent self-calibration
#     5. 3GC calibration: direction-dependent self-calibration
# 9. Putting it all together for Reducing a Data Set and Recognizing Errors
#     1. Imaging
#         1. W-Term Correction
#         2. Residual Artefacts
#         3. Practical Settings for CLEAN
#         4. Primary Beam Correction
#         5. Image Quality Assessment
#     2. Calibration
#         1. Frequency and Time Solution Intervals
#         2. Visibility Flagging
#         3. Including Direction-Dependent Solutions
#     3. Observing
#         1. Accumulation interval and smearing
#     4. Line observations: calibration and imaging issues
#         1. Source finding
#         2. Normalization
#         3. What now? How do we get to the science?
#     5. Continuum observations: calibration and imaging issues
#         1. Dynamic Range
#         2. Multi-Frequency Synthesis (MFS)
#         3. Source Finding
#         4. What now? How do we get to the science?
#     6. General Practical Advice

# %% [markdown]
# ### A Note on Software <a id='preface:sec:software'></a>
#
# This book is developed and tested with the following software dependencies (they are the Ubuntu 14.04.2 standard package versions):
#
# * python 2.7.6
# * ipython 1.2.1
# * numpy 1.8.2
# * matplotlib 1.3.1
#
# The very first entry in a notebook will import our current standard modules:

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Followed by an optional import of any section specific modules, e.g. :

# %%
import matplotlib.image as mpimg

# %% [markdown]
# ### Style Guide <a id='preface:sec:style'></a>
#
# #### Notation:
#
# A global glossary defines all mathematical notation and useful definitions. If there is a conflict or duplicate use of notation within the book then all definitions will be described in the glossary including the scope in which the notation is used. If you want to include a specific definition to a word or phase, then italicize the text the first time you use it in a section or chapter and add the term to the glossary.
#
# #### Notebook and Directory Naming Conventions:
#
# Each chapter is contained in a seperate directory, the directory name has the convention of the chapter number and chapter name, with spaces replaced by underscores, e.g. `6_deconvolution_in_imaging`. The directory will only contain notebooks, any data or additional files will be in a seperate global data directory which includes a duplicately named directory for each chapter in which to store the data.
#
# Notebook naming should be prefixed with either a sequential number or alphabet character based on ordering in the chapter. Like directories, the notebook name should be the section name (with underscores to replace spaces), a shortened version of the section is also fine, e.g. `A_sky_models.ipynb`.
#
# #### Notebook Breadth
#
# Each chapter is made up of multiple sections, each of which is possibly made up of sub-section, et cetera. To keep notebooks a reasonable and consumable size, a notebook should only contain a single section. For long sections it may be reasonable to further break up a section into multiple notebooks.
#
# #### Notebook Header
#
# The beginning of each notebook should with a set of navigation links including a link to the global outline (this notebook), glossary, the chapter specific introduction notebook, the previous section notebook, and the next section notebook. See example section 5.1.
#
# Following the navigation links the standard python modules and any section specific modules should be imported, see 'A Note on Software' above for the current standard module import command. Following these import commands the notebook should start with a heading entry for the notebook with text that corresponds to the outlien text above, see 'Section and Subsection Headings' for sizes below.
#
# #### Noteboook Footer
#
# At the end of a notebook, include a link to the next section notebook. If at the end of a chapter, provide a link to the next chapter.
#
# #### Chapter Introduction
#
# Each chapter should contain a short introduction notebook which will provide an overview of the topics in the chapter and an outline of the notebooks in the chapter.
#
# #### Chapter Conclusion
#
# The final notebook of a chapter should contain a section on further reading which contains links to papers and books, it may be useful to write a sentence about why a link is useful. Additionally, there should be a section which contains a list of all the external references noted in the chapter. Further, the conclusion to a chapter may contain a review of the topics covered in the chapter, but is not necessary.
#
# #### Section and Subsection Headings:
#
# In a notebook, section names, e.g. 5.1 Spatial Frequencies, should use the heading size 2. While each subsequent sub-section should increase the heading size, e.g. a sub-section will be size 3, a sub-sub-section will be size 4,...
#
# #### References, Internal and External:
#
# One of the limitations of the ipython notebook is the inability to render equation, figure, and table labels properly. For the moment, we have settled on a consistent, but inelegant standard.
#
# Linking to internal (i.e. within the same notebook) and external (i.e. other notebooks in the book) references will use a dual method of using the standard markdown HREF and a LaTeX style so that dynamic links will work in the notebooks and conversion to PDF via LaTeX will contain references.
#
# Internal links to references are created by adding the string `INREF` as the link, e.g. `[INREF](#destination)`. A reference is created by including `<a id='destination'></a>` where the desired reference desition is to be placed. In addition to the ipython notebook dynamic links LaTeX references should be included with the `\label{destination}` and `\ref{destination}` tags. An example of a complete internal reference is
#
# ```
# [INREF](#destination) \ref{destination}
# ```
#
# And a complete internal label is
#
# ```
# <a id='destination'></a> \label{destination}
# ```
#
# External links are similar to internal links, but use the `EXREF` string for a link. An example of a reference to another ipython notebook is `[EXREF](another_notebook.ipynb#destination)` with a LaTeX tag `\ref{destination}`. An example of a complete external reference is
#
# ```
# [EXREF](another_notebook.ipynb#destination) \ref{destination}
# ```
#
# #### Citations:
#
# For citations to published work the LaTeX `\cite{manuscript}` tag should be used for later conversion to PDF. In the dynamic notebook a link should be created with the string `CITE` to a web-based link to the work (e.g. the article abstract on a journal web site). An example of a complete citation is
#
# ```
# [CITE](http://mnras.oxfordjournals.org/content/453/2/1489.abstract?sid=5abfe72b-3c92-4c80-8777-e5ce19cc4b88) \cite{foster2015}
# ```
#
# #### Reference Naming Conventions:
#
# In order to maintain uniform and informative reference labels we will use a standard naming convention of the form `chapterStr:type:uniqueID` where `chapterStr` is a unqiue, descriptive string for a chapter or chapter subsection, `type` is the type of content beinging labelled, and `uniqueID` is a unique ID for the content. For example a table in the Imaging chapter which contains information on weights could have the label `imaging:tbl:weights`. The `chapterStr` for each chapter is to be defined by the authors. If a section of a chapter is sufficiently large it shoud have its own `chapterStr`, perhaps with the prefix including the chapter `chapterStr`. The following are valid strings for `type`: `tbl` (table), `fig` (figure), `sec` (section), `code` (code block), `eq` (equation). The `uniqueID` is left to the authors, but suggested to contain a simple descriptive string and information on location within the chapter.
#
# | Chapter    |  chapterStr  |
# |------------|-------------:|
# | Preface | `preface` |
# | 1. Radio Science using Interferometers | `science` |
# | 2. Mathematical Groundwork | `math` |
# | 3. Positional Astronomy | `pos` |
# | 4. Visibility Space | `vis` |
# | 5. Imaging | `imaging` |
# | 6. Deconvolution in Imaging | `deconv` |
# | 7. Observing Systems | `instrum` |
# | 8. Calibration | `cal` |
# | 9. Putting it all together | `pract` |
#
# | type     |  value  |
# |----------|--------:|
# | code     | `code`  |
# | equation | `eq`    |
# | figure   | `fig`   |
# | section  | `sec`   |
# | table    | `tbl`   |
#
# #### Images and Pre-made Figures:
#
# Though, ideally any figure that is included in a notebook can be generated from the code included in the notebook, this is not always possible. The preferred image type is PDF or SVG because these can be rescaled without aliasing issues, but PNG and JPEG can be used. If a figure or image is generated by some set of code, please include a reference or notes to that code so that if it needs to be regenerated then that will be possible. If a figure or image is made with a graphics progams such as Inkscape, GIMP, et cetera please include the working file in the git repository.
#
# To displaye figures use the Image function, e.g.
#
# ```
# Image(filename='figures/sidereal.png', width=300, height=100)
# ```
#
# #### Figures and Code Blocks:
#
# Below each code block or figure include a cell which contains a description of what is presented, use italics, which in markdown means by starting and ending the text with stars, e.g. \*this text would be italized in markdown\*.
#
# #### Equation Blocks:
#
# Equations can be written inline or in individual blocks. If you would like to reference an equation block, follow the label standard defined in 'References, Internal and External' above.
#
# #### Committing to git repository
#
# Notebooks can get very large in size when they contain a number of generated figures. In order to keep the size of the repository down to a reasonable size please clear the output before making a new commit. This is done by selecting Cell > All Output > Clear from the menu at the top of the notebook.
#
# Binary files should be stored in a directory in each chapter, for example images would be stored in a directory called figures.

# %% [markdown]
# ### Known Issues <a id='preface:sec:issues'></a>
#
# As this is a working project there are a number of known issues we would like to resolve. If you have a nicer or more efficient solution then please let us know. For the moment, here is a list of known unknowns.
#
# * Linking to notebooks outside of a directory does not work. This is fixed in newer versions of ipython notebook, we will shift to a newer version soon, we just need to get started on this.
# * Equation numbering does not render, this is due to a built-in setting to ipython notebook. The solution maybe to just hack the config files, see http://www.rbeesoft.com/blog/?p=6
# * An example introduction and conclusion section has not been made yet, this is a work in progress and will hopefully be available soon.
