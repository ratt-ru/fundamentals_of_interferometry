# %%
#Created: sirothia@gmail.com 20170207
#for label and ref example

##################################
#This is the top level notebook that
#has all the chapter and section filename 
#in proper order 
#Do not change initilizations listed in this box
##################################

import pickle
from incfunc import init_ipyref_filename, ipy_label, ipy_ref

init_ipyref = False
debug_lvl = 0

if init_ipyref :
    sdict = {}
    sdict['lastchapter_cnt']=sdict['chapter_cnt']=0
    sdict['lastsection_cnt']=sdict['section_cnt']=0
    sdict['lastsectionl1_cnt']=sdict['sectionl1_cnt']=0
    sdict['lastsectionl2_cnt']=sdict['sectionl2_cnt']=0
    sdict['lastsectionl3_cnt']=sdict['sectionl3_cnt']=0
    sdict['lastequation_cnt']=sdict['equation_cnt']=0
    sdict['lastfigure_cnt']=sdict['figure_cnt']=0
    sdict['lasttable_cnt']=sdict['table_cnt']=0
    sdict['cite_cnt']=sdict['glossary_cnt']=sdict['abbr_cnt']=sdict['eref_cnt']=sdict['eread_cnt']=0
    sdict['ipyrefname'] = init_ipyref_filename()
    sdict['update_ipyref']=init_ipyref
    f = open(sdict['ipyrefname'], 'wb')
    pickle.dump(sdict, f)
    f.close()
    if debug_lvl > 10: print 'init', sdict['ipyrefname']

ipyrefname=init_ipyref_filename()

f = open(ipyrefname, 'rb')
sdict = pickle.load(f)
f.close()
sdict['update_ipyref']=init_ipyref

if debug_lvl > 10: print 'loaded', sdict['ipyrefname']

# %%
#this is chapter 1
# %run dummy_chap_f.ipynb

# %%
#this is chapter 2
# %run dummy_chap_e.ipynb

# %%
#this is chapter 3
# %run ../3_Positional_Astronomy/3_0_introduction.ipynb
# Out:
# &sect 3.1  &#8631
# [Debug] ipy_ref =>  rstr <script>            aval=document.getElementById("pos_sec_eq_xyz");            aval.href="../3_Positional_Astronomy/3_1_equatorial_coordinates.ipynb#pos_sec_eq";            aval.innerHTML = "&sect 3.1  &#8631";            </script>
# [Suggestion] ipy_ref =>  id pos_sec_eq use class pos_sec_eq_xyz
# <script>            aval=document.getElementById("pos_sec_eq_xyz");            aval.href="../3_Positional_Astronomy/3_1_equatorial_coordinates.ipynb#pos_sec_eq";            aval.innerHTML = "&sect 3.1  &#8631";            </script>

# %%
#this is chapter 3
# %run ../3_Positional_Astronomy/3_1_equatorial_coordinates.ipynb
# Out:
# Populating the interactive namespace from numpy and matplotlib
# J2000: RA:14:16:24.47 DEC:19:06:07.5
# B1950: RA:14:13:18.28 DEC:19:24:36.4
# NSIDE = 512
# ORDERING = NESTED in fits file
# INDXSCHM = IMPLICIT
# WARNING: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy
# Ordering converted to RING
# 0.0 180.0 -180.0 180.0
# The interval between parallels is 30 deg -0.00'.
# The interval between meridians is 30 deg -0.00'.

# %%
#this is chapter 3
# %run ../3_Positional_Astronomy/3_2_hour_angle.ipynb
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#this is chapter 3
# %run ../3_Positional_Astronomy/3_3_horizontal_coordinates.ipynb
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#this is chapter 3
# %run ../3_Positional_Astronomy/3_4_direction_cosine_coordinates.ipynb
# Out:
# RA (rad) of Sources and Field Center =  [ 1.43989663  1.44865237  1.46700741  1.48683872]
# DEC (rad) of Sources =  [ 1.04719755  1.05241899  1.06817495  1.08110542]
# l (degrees) =  [ 0.          0.24855826  0.74818685  1.26458942]
# m (degrees) =  [ 0.          0.30010768  1.21061225  1.96811494]

# %%
#this is chapter 3
# %run ../3_Positional_Astronomy/3_x_further_reading_and_references.ipynb

# %%
#this is chapter 4
# %run dummy_chap_d.ipynb

# %%
#this is chapter 5
# %run dummy_chap_c.ipynb

# %%
#this is chapter 6
# %run dummy_chap_h.ipynb

# %%
#this is chapter 7
# %run dummy_chap_b.ipynb

# %%
#this is chapter 8
# %run dummy_chap_a.ipynb

# %%
#this is chapter 9
# %run ../9_Practical/practical_calib.ipynb
# Out:
# &sect 9.3  &#8631
# [Debug] ipy_ref =>  rstr <script>            aval=document.getElementById("prac_sec_test3_xyz");            aval.href="../9_Practical/practical_im.ipynb#prac_sec_test3";            aval.innerHTML = "&sect 9.3  &#8631";            </script>
# [Suggestion] ipy_ref =>  id prac_sec_test3 use class prac_sec_test3_xyz

# %%
#It may not be new chapter also
# %run ../9_Practical/practical_im.ipynb

# %%
#this is dummy for chapter 10
# %run dummy_chap_j.ipynb

# %%
if init_ipyref :
    sdict['update_ipyref'] = False
    f = open(sdict['ipyrefname'], 'wb')
    pickle.dump(sdict, f)
    f.close()
    print 'stored', sdict['ipyrefname']
