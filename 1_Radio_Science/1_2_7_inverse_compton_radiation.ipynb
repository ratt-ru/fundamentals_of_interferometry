# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import Image 
from scipy.constants import *
import glob,os
# Out:
# /home/kshitij/.virtualenv/fundamentals/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# ***
#
# * [Outline](../0_Introduction/0_introduction.ipynb)
# * [Glossary](../0_Introduction/1_glossary.ipynb)
# * [1. Radio Science using Interferometric Arrays](#)
#     * Previous: [1.2.6 Synchrotron Emission](1_2_6_synchrotron_emission.ipynb)
#     * Next: [1.2.8 Recombination Lines](1_2_8_recombination_lines.ipynb)

# %% [markdown]
# ### 1.2.7 Inverse Compton Radiation:

# %%
Image(filename='Figures/inverse_compton.jpg',width=300)

# %%
Image(filename='Figures/sz.png', width=300)

# %% [markdown]
# ***
#
# Next : [1.2.8 Recombination Lines](1_2_8_recombination_lines.ipynb)
